# %% [markdown]
# IMPORT LIBRARIES

# %%
from matplotlib import pyplot as plt
from matplotlib import ticker
from matplotlib.patches import Rectangle
from matplotlib.colors import LinearSegmentedColormap
from sklearn import datasets
import datetime as datetime64 
import pandas as pd
import numpy as np
import warnings
import json
import os
warnings.filterwarnings('ignore')

# %%
#Specifying file paths
tornado_data = "Resources/2023_tornado_activity.csv"

#Reading all data into Pandas
tornado_df = pd.read_csv(tornado_data)

# %%
tornado_df
# Out:
#           om    yr  mo  dy        date      time  tz  st  stf  stn  ...   len  \
# 0     622081  2023   1   2  2023-01-02  11:47:00   3  AR    5    0  ...  0.24
# 1     622082  2023   1   2  2023-01-02  14:38:00   3  AR    5    0  ...  2.09
# 2     622083  2023   1   2  2023-01-02  15:11:00   3  LA   22    0  ...  5.20
# 3     622084  2023   1   2  2023-01-02  15:43:00   3  LA   22    0  ...  0.31
# 4     622085  2023   1   2  2023-01-02  16:37:00   3  OK   40    0  ...  0.10
# ...      ...   ...  ..  ..         ...       ...  ..  ..  ...  ...  ...   ...
# 1356  623397  2023  12  10  2023-12-10  04:36:00   3  AL    1    0  ...  2.43
# 1357  623398  2023  12  10  2023-12-10  05:30:00   3  FL   12    0  ...  2.97
# 1358  623399  2023  12  10  2023-12-10  11:28:00   3  NC   37    0  ...  1.88
# 1359  623400  2023  12  17  2023-12-17  12:16:00   3  SC   45    0  ...  2.35
# 1360  623401  2023  12  19  2023-12-19  19:40:00   3  CA    6    0  ...  0.36
#
#       wid  ns  sn  sg   f1  f2  f3  f4  fc
# 0     350   1   1   1  139   0   0   0   0
# 1     200   1   1   1   51   0   0   0   0
# 2      70   1   1   1   85   0   0   0   0
# 3      50   1   1   1   81   0   0   0   0
# 4     100   1   1   1  113   0   0   0   0
# ...   ...  ..  ..  ..  ...  ..  ..  ..  ..
# 1356  400   1   1   1   81   0   0   0   0
# 1357  250   1   1   1   59   0   0   0   0
# 1358  250   1   1   1  183   0   0   0   0
# 1359  150   1   1   1   51   0   0   0   0
# 1360   90   1   1   1    7   0   0   0   0
#
# [1361 rows x 29 columns]

# %%
#Narrow dataframe down to only columns needed and rename columns
selected_columns = ['yr', 'mo', 'dy', 'date', 'time', 'st', 'mag', 'loss', 'slat', 'slon']

tornado_cleaned_df = tornado_df[selected_columns]

tornado_cleaned_df.head()
# Out:
#      yr  mo  dy        date      time  st  mag     loss     slat     slon
# 0  2023   1   2  2023-01-02  11:47:00  AR    1    25000  33.2939 -92.7057
# 1  2023   1   2  2023-01-02  14:38:00  AR    1  5000000  34.6940 -93.0673
# 2  2023   1   2  2023-01-02  15:11:00  LA    1    15000  31.7499 -93.4807
# 3  2023   1   2  2023-01-02  15:43:00  LA    0    10000  32.0582 -93.2735
# 4  2023   1   2  2023-01-02  16:37:00  OK   -9        0  36.7218 -96.6194

# %%
# Rename columns to clarify
tornado_cleaned_df = tornado_cleaned_df.rename(columns=
                                        {'yr': 'Year',
                                            'mo': 'Month',
                                            'dy': 'Day',
                                            'date': 'Date',
                                            'time': 'Time',
                                            'st': 'State',
                                            'mag': 'Magnitude',
                                            'loss': 'Damages',
                                            'slat': 'Starting Lat',
                                            'slon': 'Starting Long'})

tornado_cleaned_df.head()
# Out:
#    Year  Month  Day        Date      Time State  Magnitude  Damages  \
# 0  2023      1    2  2023-01-02  11:47:00    AR          1    25000
# 1  2023      1    2  2023-01-02  14:38:00    AR          1  5000000
# 2  2023      1    2  2023-01-02  15:11:00    LA          1    15000
# 3  2023      1    2  2023-01-02  15:43:00    LA          0    10000
# 4  2023      1    2  2023-01-02  16:37:00    OK         -9        0
#
#    Starting Lat  Starting Long
# 0       33.2939       -92.7057
# 1       34.6940       -93.0673
# 2       31.7499       -93.4807
# 3       32.0582       -93.2735
# 4       36.7218       -96.6194

# %%
# Drop all rows with Magnitude of -9
tornado_cleaned_df = tornado_cleaned_df[tornado_cleaned_df["Magnitude"] != -9]
tornado_cleaned_df
# Out:
#       Year  Month  Day        Date      Time State  Magnitude  Damages  \
# 0     2023      1    2  2023-01-02  11:47:00    AR          1    25000
# 1     2023      1    2  2023-01-02  14:38:00    AR          1  5000000
# 2     2023      1    2  2023-01-02  15:11:00    LA          1    15000
# 3     2023      1    2  2023-01-02  15:43:00    LA          0    10000
# 5     2023      1    2  2023-01-02  16:46:00    LA          2   850000
# ...    ...    ...  ...         ...       ...   ...        ...      ...
# 1356  2023     12   10  2023-12-10  04:36:00    AL          0        0
# 1357  2023     12   10  2023-12-10  05:30:00    FL          1        0
# 1358  2023     12   10  2023-12-10  11:28:00    NC          1        0
# 1359  2023     12   17  2023-12-17  12:16:00    SC          1   200000
# 1360  2023     12   19  2023-12-19  19:40:00    CA          1    17000
#
#       Starting Lat  Starting Long
# 0          33.2939       -92.7057
# 1          34.6940       -93.0673
# 2          31.7499       -93.4807
# 3          32.0582       -93.2735
# 5          32.1720       -92.7048
# ...            ...            ...
# 1356       32.4649       -85.4258
# 1357       30.8054       -85.8331
# 1358       35.6940       -78.6520
# 1359       33.6837       -78.9737
# 1360       39.8043      -121.8366
#
# [1092 rows x 10 columns]

# %%
tornado_cleaned_df.dtypes
# Out:
# Year               int64
# Month              int64
# Day                int64
# Date              object
# Time              object
# State             object
# Magnitude          int64
# Damages            int64
# Starting Lat     float64
# Starting Long    float64
# dtype: object

# %%
# Convert 'time' column to timedelta
tornado_cleaned_df['Time'] = pd.to_timedelta(tornado_cleaned_df['Time'])

# Extract the hour component
tornado_cleaned_df['Hour'] = tornado_cleaned_df['Time'].dt.components['hours']

tornado_cleaned_df
# Out:
#       Year  Month  Day        Date            Time State  Magnitude  Damages  \
# 0     2023      1    2  2023-01-02 0 days 11:47:00    AR          1    25000
# 1     2023      1    2  2023-01-02 0 days 14:38:00    AR          1  5000000
# 2     2023      1    2  2023-01-02 0 days 15:11:00    LA          1    15000
# 3     2023      1    2  2023-01-02 0 days 15:43:00    LA          0    10000
# 5     2023      1    2  2023-01-02 0 days 16:46:00    LA          2   850000
# ...    ...    ...  ...         ...             ...   ...        ...      ...
# 1356  2023     12   10  2023-12-10 0 days 04:36:00    AL          0        0
# 1357  2023     12   10  2023-12-10 0 days 05:30:00    FL          1        0
# 1358  2023     12   10  2023-12-10 0 days 11:28:00    NC          1        0
# 1359  2023     12   17  2023-12-17 0 days 12:16:00    SC          1   200000
# 1360  2023     12   19  2023-12-19 0 days 19:40:00    CA          1    17000
#
#       Starting Lat  Starting Long  Hour
# 0          33.2939       -92.7057    11
# 1          34.6940       -93.0673    14
# 2          31.7499       -93.4807    15
# 3          32.0582       -93.2735    15
# 5          32.1720       -92.7048    16
# ...            ...            ...   ...
# 1356       32.4649       -85.4258     4
# 1357       30.8054       -85.8331     5
# 1358       35.6940       -78.6520    11
# 1359       33.6837       -78.9737    12
# 1360       39.8043      -121.8366    19
#
# [1092 rows x 11 columns]

# %%
# Drop the 'Time' and 'Date' columns
tornado_cleaned_df = tornado_cleaned_df.drop(columns=['Time'])
tornado_cleaned_df
# Out:
#       Year  Month  Day        Date State  Magnitude  Damages  Starting Lat  \
# 0     2023      1    2  2023-01-02    AR          1    25000       33.2939
# 1     2023      1    2  2023-01-02    AR          1  5000000       34.6940
# 2     2023      1    2  2023-01-02    LA          1    15000       31.7499
# 3     2023      1    2  2023-01-02    LA          0    10000       32.0582
# 5     2023      1    2  2023-01-02    LA          2   850000       32.1720
# ...    ...    ...  ...         ...   ...        ...      ...           ...
# 1356  2023     12   10  2023-12-10    AL          0        0       32.4649
# 1357  2023     12   10  2023-12-10    FL          1        0       30.8054
# 1358  2023     12   10  2023-12-10    NC          1        0       35.6940
# 1359  2023     12   17  2023-12-17    SC          1   200000       33.6837
# 1360  2023     12   19  2023-12-19    CA          1    17000       39.8043
#
#       Starting Long  Hour
# 0          -92.7057    11
# 1          -93.0673    14
# 2          -93.4807    15
# 3          -93.2735    15
# 5          -92.7048    16
# ...             ...   ...
# 1356       -85.4258     4
# 1357       -85.8331     5
# 1358       -78.6520    11
# 1359       -78.9737    12
# 1360      -121.8366    19
#
# [1092 rows x 10 columns]

# %%
# Export clean df as csv in Resources folder for communal access
tornado_cleaned_df.to_csv("Resources/tornado_cleaned.csv")

# %%
# Calculating Damages quantiles
percentiles = tornado_cleaned_df['Damages'].quantile(q=[0.3, 0.42, 0.57, 0.9])
percentiles
# Out:
# 0.30         0.0
# 0.42         0.0
# 0.57      5000.0
# 0.90    300000.0
# Name: Damages, dtype: float64

# %%
#Load data again
tornado_cleaned_df
# Out:
#       Year  Month  Day        Date State  Magnitude  Damages  Starting Lat  \
# 0     2023      1    2  2023-01-02    AR          1    25000       33.2939
# 1     2023      1    2  2023-01-02    AR          1  5000000       34.6940
# 2     2023      1    2  2023-01-02    LA          1    15000       31.7499
# 3     2023      1    2  2023-01-02    LA          0    10000       32.0582
# 5     2023      1    2  2023-01-02    LA          2   850000       32.1720
# ...    ...    ...  ...         ...   ...        ...      ...           ...
# 1356  2023     12   10  2023-12-10    AL          0        0       32.4649
# 1357  2023     12   10  2023-12-10    FL          1        0       30.8054
# 1358  2023     12   10  2023-12-10    NC          1        0       35.6940
# 1359  2023     12   17  2023-12-17    SC          1   200000       33.6837
# 1360  2023     12   19  2023-12-19    CA          1    17000       39.8043
#
#       Starting Long  Hour
# 0          -92.7057    11
# 1          -93.0673    14
# 2          -93.4807    15
# 3          -93.2735    15
# 5          -92.7048    16
# ...             ...   ...
# 1356       -85.4258     4
# 1357       -85.8331     5
# 1358       -78.6520    11
# 1359       -78.9737    12
# 1360      -121.8366    19
#
# [1092 rows x 10 columns]

# %%
# Convert DataFrame to GeoJSON
def df_to_geojson(df):
    geojson_data = {
        "type": "FeatureCollection",
        "features": [
            {
                "type": "Feature",
                "geometry": {
                    "type": "Point",
                    "coordinates": [row['Starting Long'], row['Starting Lat']],
                },
                "properties": {
                    "year": row['Year'],
                    "month": row['Month'],
                    "day": row['Day'],
                    "date": row['Date'],
                    "state": row['State'],
                    "magnitude": row['Magnitude'],
                    "damages": row['Damages'],
                },
            }
            for idx, row in df.iterrows()
        ],
    }
    return geojson_data

# %%
# Convert DataFrame to GeoJSON and save
geojson_data = df_to_geojson(tornado_cleaned_df)

# %%
# Define the full path to save the GeoJSON file in the Resources folder
geojson_file_path = os.path.join('Resources', 'tornado_data.geojson')

# %%
# Save the GeoJSON data to the specified path
with open(geojson_file_path, 'w') as f:
    json.dump(geojson_data, f)
